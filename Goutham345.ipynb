# %% [markdown]
# <a href="https://colab.research.google.com/github/Goutham345/Goutham345/blob/main/Goutham345.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Hi I'm Goutham Reddy
#
# - Computer Science Student
# - Skills:Python,HTML,CSS,SQL
# - Aspiring Software Developer | Open to Internship&Fresher Roles
#
# ---
#
# ### Technical Skills
# - Python
# - HTML, CSS
# - SQL
# - Git & GitHub
#
# ---
#
# ### Currently Learning
# - Data Structures & Algorithms
# - Backend Development
#
# ---
#
# ### Contact
# - Email: tembarenigouthamreddy@gmail.com
